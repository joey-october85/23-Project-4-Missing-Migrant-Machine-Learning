# %%
# !pip install keras-tuner
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install keras-tuner

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")

# %%
#  Import and read the csv.
import pandas as pd
clean_df = pd.read_csv("https://raw.githubusercontent.com/msryannhawkins/Project-4-Migrant-MachineLearning/main/cleaned_folder/clean_data.csv", index_col=0)
clean_df.head()
# Out:
#   incident_type  Incident_Year Reported_Month           Region_of_Origin  \
# 0      Incident           2014        January            Central America
# 1      Incident           2014        January  Latin America / Caribbean
# 2      Incident           2014        January  Latin America / Caribbean
# 3      Incident           2014        January            Central America
# 5      Incident           2014        January  Latin America / Caribbean
#
#   Region_of_Incident  Number_of_Dead  Minimum_Estimated_Number_of_Missing  \
# 0      North America               1                                    0
# 1      North America               1                                    0
# 2      North America               1                                    0
# 3      North America               1                                    0
# 5      North America               1                                    0
#
#    Number_of_Survivors  Number_of_Females  Number_of_Males  \
# ...

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(clean_df)
dummies_df.head(1)

1 rows × 61 columns
# Out:
#   Cell In[1], line 5
#     1 rows × 61 columns
#            ^
# SyntaxError: invalid character '×' (U+00D7)

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df['Cause_of_Death'].values
X = dummies_df.drop(columns='Cause_of_Death').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Base Model
# - Hidden Layers: 2
# - Nodes: 80, 50
# - Activation: relu
# - Epochs: 100

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                4880
#
#  dense_1 (Dense)             (None, 50)                4050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# ...
# Total params: 8981 (35.08 KB)
# Trainable params: 8981 (35.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 221/221 [==============================] - 1s 2ms/step - loss: 0.5745 - accuracy: 0.6955
# Epoch 2/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5334 - accuracy: 0.7219
# Epoch 3/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5216 - accuracy: 0.7304
# Epoch 4/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.7322
# Epoch 5/100
# ...

# %% [markdown]
# # Optimization No1
# - Hidden Layers: 3
# - Nodes: 80, 50, 30
# - Activation: Sigmoid
# - Epochs: 100

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 30

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="sigmoid"))

# # Additional Layer added for optimization
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="sigmoid"))

# Output layer
nn1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1.summary()

# Compile the model
nn1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model01 = nn1.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 80)                4880
#
#  dense_4 (Dense)             (None, 50)                4050
#
#  dense_5 (Dense)             (None, 30)                1530
#
#  dense_6 (Dense)             (None, 1)                 31
#
# ...
# Total params: 10491 (40.98 KB)
# Trainable params: 10491 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 221/221 [==============================] - 2s 2ms/step - loss: 0.6238 - accuracy: 0.6511
# Epoch 2/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5592 - accuracy: 0.7116
# Epoch 3/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7182
# Epoch 4/100
# ...

# %% [markdown]
# #### Building off of Optimization No1 as it has been the most accurate model.
#
# #Optimization 1.1
# - Hidden Layers: 3
# - Nodes: 80, 50, 30
# - Activation: tanh
# - Epochs: 100

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 30

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh"))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="tanh"))

# # Additional Layer added for optimization
nn1.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="tanh"))

# Output layer
nn1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1.summary()

# Compile the model
nn1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model01 = nn1.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 80)                4880
#
#  dense_8 (Dense)             (None, 50)                4050
#
#  dense_9 (Dense)             (None, 30)                1530
#
#  dense_10 (Dense)            (None, 1)                 31
#
# ...
# Total params: 10491 (40.98 KB)
# Trainable params: 10491 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 221/221 [==============================] - 1s 2ms/step - loss: 0.5666 - accuracy: 0.7028
# Epoch 2/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5392 - accuracy: 0.7199
# Epoch 3/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.7197
# Epoch 4/100
# ...

# %% [markdown]
# # Optimization 1.2
# - Hidden Layers: 3
# - Nodes: 80, 50, 30
# - Activation: sigmoid
# - Epochs: 200

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 30

nn1_1 = tf.keras.models.Sequential()

# First hidden layer
nn1_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
nn1_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="sigmoid"))

# # Additional Layer added for optimization
nn1_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="sigmoid"))

# Output layer
nn1_1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1_1.summary()

# Compile the model
nn1_1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model01_01 = nn1_1.fit(X_train_scaled, y_train, epochs=200)

# Evaluate the model using the test data
model_loss, model_accuracy = nn1_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 80)                4880
#
#  dense_21 (Dense)            (None, 50)                4050
#
#  dense_22 (Dense)            (None, 30)                1530
#
#  dense_23 (Dense)            (None, 1)                 31
#
# ...
# Total params: 10491 (40.98 KB)
# Trainable params: 10491 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 221/221 [==============================] - 1s 2ms/step - loss: 0.6229 - accuracy: 0.6494
# Epoch 2/200
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.7133
# Epoch 3/200
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7160
# Epoch 4/200
# ...

# %% [markdown]
# # Optimization 1.2
# - Hidden Layers: 3
# - Nodes: 100, 80, 50
# - Activation: sigmoid, relu
# - Epochs: 200

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 80
hidden_nodes_layer3 = 50
hidden_nodes_layer4 = 30

nn1_2 = tf.keras.models.Sequential()

# First hidden layer
nn1_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
nn1_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="sigmoid"))

# Additional Layer added for optimization
nn1_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="relu"))

# Additional Layer added for optimization
nn1_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, input_dim=number_input_features, activation="relu"))

# Output layer
nn1_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1_2.summary()

# Compile the model
nn1_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model01_02 = nn1_2.fit(X_train_scaled, y_train, epochs=200)

# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 100)               6100
#
#  dense_25 (Dense)            (None, 80)                8080
#
#  dense_26 (Dense)            (None, 50)                4050
#
#  dense_27 (Dense)            (None, 30)                1530
#
#  dense_28 (Dense)            (None, 1)                 31
#
# ...
# Total params: 19791 (77.31 KB)
# Trainable params: 19791 (77.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 221/221 [==============================] - 2s 2ms/step - loss: 0.5997 - accuracy: 0.6737
# Epoch 2/200
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5577 - accuracy: 0.7157
# Epoch 3/200
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5527 - accuracy: 0.7124
# Epoch 4/200
# ...

# %% [markdown]
# # Optimization No2
# - Hidden Layers: 3
# - Nodes: 80, 50, 30
# - Activation: relu
# - Epochs: 100

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 30

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="relu"))

# # Additional Layer added for optimization
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="relu"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()

# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model02 = nn2.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 80)                4880
#
#  dense_21 (Dense)            (None, 50)                4050
#
#  dense_22 (Dense)            (None, 30)                1530
#
#  dense_23 (Dense)            (None, 1)                 31
#
# ...
# Total params: 10491 (40.98 KB)
# Trainable params: 10491 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 221/221 [==============================] - 1s 2ms/step - loss: 0.5686 - accuracy: 0.7041
# Epoch 2/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7235
# Epoch 3/100
# 221/221 [==============================] - 0s 2ms/step - loss: 0.5185 - accuracy: 0.7306
# Epoch 4/100
# ...

# %% [markdown]
# # Optimization No3
# - Hidden Layers: 4
# - Nodes: 100, 70, 50, 20
# - Activation: relu
# - Epochs: 100

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 70
hidden_nodes_layer3 = 50
hidden_nodes_layer4 = 20

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="relu"))

# # Additional Layer added for optimization
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="relu"))

# # Additional Layer added for optimization
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, input_dim=number_input_features, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()

# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model03 = nn3.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 100)               6100
#
#  dense_25 (Dense)            (None, 70)                7070
#
#  dense_26 (Dense)            (None, 50)                3550
#
#  dense_27 (Dense)            (None, 20)                1020
#
#  dense_28 (Dense)            (None, 1)                 21
#
# ...
# Total params: 17761 (69.38 KB)
# Trainable params: 17761 (69.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 221/221 [==============================] - 2s 3ms/step - loss: 0.5673 - accuracy: 0.7068
# Epoch 2/100
# 221/221 [==============================] - 1s 3ms/step - loss: 0.5317 - accuracy: 0.7239
# Epoch 3/100
# 221/221 [==============================] - 1s 3ms/step - loss: 0.5168 - accuracy: 0.7296
# Epoch 4/100
# ...

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer0 = 7
hidden_nodes_layer1 = 52
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 64
hidden_nodes_layer4 = 82
hidden_nodes_layer5 = 50
hidden_nodes_layer6 = 96


nn0 = tf.keras.models.Sequential()

#Layers
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer0, input_dim=number_input_features, activation="tanh"))
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu"))
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="tanh"))
nn0.add(tf.keras.layers.Dense(units=hidden_nodes_layer6, activation="relu"))


# Output layer
nn0.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn0.summary()

# Compile the model
nn0.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model0 = nn0.fit(X_train_scaled, y_train, epochs=20)

# Evaluate the model using the test data
model_loss, model_accuracy = nn0.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 7)                 427
#
#  dense_9 (Dense)             (None, 52)                416
#
#  dense_10 (Dense)            (None, 30)                1590
#
#  dense_11 (Dense)            (None, 64)                1984
#
#  dense_12 (Dense)            (None, 82)                5330
#
#  dense_13 (Dense)            (None, 50)                4150
#
#  dense_14 (Dense)            (None, 96)                4896
#
#  dense_15 (Dense)            (None, 1)                 97
#
# ...
# Total params: 18890 (73.79 KB)
# Trainable params: 18890 (73.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 221/221 [==============================] - 4s 2ms/step - loss: 0.5923 - accuracy: 0.6791
# Epoch 2/20
# ...

# %%
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=60))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=30,
            max_value=100,
            step=2),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=100,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 508 Complete [00h 01m 19s]
# val_accuracy: 0.7390751242637634
#
# Best val_accuracy So Far: 0.7543487548828125
# Total elapsed time: 01h 36m 46s

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 7,
#  'num_layers': 6,
#  'units_0': 52,
#  'units_1': 30,
#  'units_2': 64,
#  'units_3': 82,
#  'units_4': 50,
#  'units_5': 96,
#  'tuner/epochs': 34,
#  'tuner/initial_epoch': 12,
#  'tuner/bracket': 2,
#  'tuner/round': 1,
#  'tuner/trial_id': '0218'}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 74/74 - 0s - loss: 0.5260 - accuracy: 0.7543 - 408ms/epoch - 6ms/step
# Loss: 0.5260090827941895, Accuracy: 0.7543487548828125
